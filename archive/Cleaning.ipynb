# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_rows", 10)
pd.read_csv('Comprehensive National Nutrition Survey (CNNS) 2016-18  Key Anthropometric Indicators by Sex.csv')
# Out:
#     Rowid Country  State lgd code              State  Yearcode  \
# 0       1   India               1  Jammu And Kashmir      2018
# 1       2   India               1  Jammu And Kashmir      2018
# 2       3   India               2   Himachal Pradesh      2018
# 3       4   India               2   Himachal Pradesh      2018
# 4       5   India               3             Punjab      2018
# ..    ...     ...             ...                ...       ...
# 57     58   India              33         Tamil Nadu      2018
# 58     59   India              36          Telangana      2018
# 59     60   India              36          Telangana      2018
# 60     61   India              37             Ladakh      2018
# 61     62   India              37             Ladakh      2018
#
#                                Year  From year  Gender  \
# 0   Calendar Year (Jan - Dec), 2018       2016  Female
# 1   Calendar Year (Jan - Dec), 2018       2016    Male
# ...

# %%
df = pd.read_csv('Comprehensive National Nutrition Survey (CNNS) 2016-18  Key Anthropometric Indicators by Sex.csv')

df.head()
# Out:
#    Rowid Country  State lgd code              State  Yearcode  \
# 0      1   India               1  Jammu And Kashmir      2018
# 1      2   India               1  Jammu And Kashmir      2018
# 2      3   India               2   Himachal Pradesh      2018
# 3      4   India               2   Himachal Pradesh      2018
# 4      5   India               3             Punjab      2018
#
#                               Year  From year  Gender  \
# 0  Calendar Year (Jan - Dec), 2018       2016  Female
# 1  Calendar Year (Jan - Dec), 2018       2016    Male
# 2  Calendar Year (Jan - Dec), 2018       2016  Female
# 3  Calendar Year (Jan - Dec), 2018       2016    Male
# 4  Calendar Year (Jan - Dec), 2018       2016  Female
#
#    Stunted (height for age) children under the age of 5 years (%)  \
# 0                                               13.8
# 1                                               17.4
# 2                                               23.6
# ...

# %%
pd.read_csv('Comprehensive National Nutrition Survey (CNNS) 2016-18 Key Anthropometric Indicators by Residence.csv')
df2 = pd.read_csv('Comprehensive National Nutrition Survey (CNNS) 2016-18 Key Anthropometric Indicators by Residence.csv')
df2.head()
# Out:
#    Rowid Country  State lgd code              State  Yearcode  \
# 0      1   India               1  Jammu And Kashmir      2018
# 1      2   India               1  Jammu And Kashmir      2018
# 2      3   India               1  Jammu And Kashmir      2018
# 3      4   India               2   Himachal Pradesh      2018
# 4      5   India               2   Himachal Pradesh      2018
#
#                               Year  From year Residence type  \
# 0  Calendar Year (Jan - Dec), 2018       2016          Rural
# 1  Calendar Year (Jan - Dec), 2018       2016          Total
# 2  Calendar Year (Jan - Dec), 2018       2016          Urban
# 3  Calendar Year (Jan - Dec), 2018       2016          Rural
# 4  Calendar Year (Jan - Dec), 2018       2016          Total
#
#    Stunted children under the age of 5 years (%)  \
# 0                                           15.7
# 1                                           15.5
# 2                                           14.6
# ...

# %%
df.isnull().sum()
# Out:
# Rowid                                                                                                                               0
# Country                                                                                                                             0
# State lgd code                                                                                                                      0
# State                                                                                                                               0
# Yearcode                                                                                                                            0
#                                                                                                                                    ..
# Overweight or obese adolescents age group 15 to 19 years with (body mass index ( bmi ) for age ) z-score greater than +1 sd (%)     0
# ...

# %%
df = df[0:10][['Country', 'State', 'Yearcode', 'Year', 'Gender']]
df
# Out:
#   Country              State  Yearcode                             Year  \
# 0   India  Jammu And Kashmir      2018  Calendar Year (Jan - Dec), 2018
# 1   India  Jammu And Kashmir      2018  Calendar Year (Jan - Dec), 2018
# 2   India   Himachal Pradesh      2018  Calendar Year (Jan - Dec), 2018
# 3   India   Himachal Pradesh      2018  Calendar Year (Jan - Dec), 2018
# 4   India             Punjab      2018  Calendar Year (Jan - Dec), 2018
# 5   India             Punjab      2018  Calendar Year (Jan - Dec), 2018
# 6   India        Uttarakhand      2018  Calendar Year (Jan - Dec), 2018
# 7   India        Uttarakhand      2018  Calendar Year (Jan - Dec), 2018
# 8   India            Haryana      2018  Calendar Year (Jan - Dec), 2018
# 9   India            Haryana      2018  Calendar Year (Jan - Dec), 2018
#
#    Gender
# 0  Female
# 1    Male
# 2  Female
# 3    Male
# 4  Female
# 5    Male
# 6  Female
# 7    Male
# 8  Female
# 9    Male

# %%
df2 = df2[0:10][['Country','Residence type', 'Yearcode']]
df2
# Out:
#   Country Residence type  Yearcode
# 0   India          Rural      2018
# 1   India          Total      2018
# 2   India          Urban      2018
# 3   India          Rural      2018
# 4   India          Total      2018
# 5   India          Urban      2018
# 6   India          Rural      2018
# 7   India          Total      2018
# 8   India          Urban      2018
# 9   India          Rural      2018

# %%
df_merge=df.merge(df2, left_on='Country', right_on='Country')
df_merge = df_merge[0:10]
df = df_merge
df
# Out:
#   Country              State  Yearcode_x                             Year  \
# 0   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 1   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 2   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 3   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 4   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 5   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 6   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 7   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 8   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 9   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
#
#    Gender Residence type  Yearcode_y
# 0  Female          Rural        2018
# 1  Female          Total        2018
# 2  Female          Urban        2018
# ...

# %%
df.query('Yearcode_x == Yearcode_y')
# Out:
#   Country              State  Yearcode_x                             Year  \
# 0   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 1   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 2   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 3   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 4   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 5   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 6   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 7   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 8   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
# 9   India  Jammu And Kashmir        2018  Calendar Year (Jan - Dec), 2018
#
#    Gender Residence type  Yearcode_y
# 0  Female          Rural        2018
# 1  Female          Total        2018
# 2  Female          Urban        2018
# ...

# %%
np.random.seed(50)
col_name=['Yearcode_x','Year']
mask = np.random.choice([True, False], size=df[col_name].shape)
mask[mask.all(1),-1] = 0
print(mask)
df[col_name]=df[col_name].mask(mask)
df
# Out:
# [[ True False]
#  [False False]
#  [False  True]
#  [ True False]
#  [False  True]
#  [ True False]
#  [False  True]
#  [False  True]
#  [False False]
#  [ True False]]
#   Country              State  Yearcode_x                             Year  \
# 0   India  Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# 1   India  Jammu And Kashmir      2018.0  Calendar Year (Jan - Dec), 2018
# 2   India  Jammu And Kashmir      2018.0                              NaN
# 3   India  Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# 4   India  Jammu And Kashmir      2018.0                              NaN
# 5   India  Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# 6   India  Jammu And Kashmir      2018.0                              NaN
# 7   India  Jammu And Kashmir      2018.0                              NaN
# 8   India  Jammu And Kashmir      2018.0  Calendar Year (Jan - Dec), 2018
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         10 non-null     object
#  1   State           10 non-null     object
#  2   Yearcode_x      6 non-null      float64
#  3   Year            6 non-null      object
#  4   Gender          10 non-null     object
#  5   Residence type  10 non-null     object
#  6   Yearcode_y      10 non-null     int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 640.0+ bytes

# %%
df.rename(columns={"Year": "Year Specific"})
# Out:
#   Country              State  Yearcode_x                    Year Specific  \
# 0   India  Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# 1   India  Jammu And Kashmir      2018.0  Calendar Year (Jan - Dec), 2018
# 2   India  Jammu And Kashmir      2018.0                              NaN
# 3   India  Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# 4   India  Jammu And Kashmir      2018.0                              NaN
# 5   India  Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# 6   India  Jammu And Kashmir      2018.0                              NaN
# 7   India  Jammu And Kashmir      2018.0                              NaN
# 8   India  Jammu And Kashmir      2018.0  Calendar Year (Jan - Dec), 2018
# 9   India  Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
#
#    Gender Residence type  Yearcode_y
# 0  Female          Rural        2018
# 1  Female          Total        2018
# 2  Female          Urban        2018
# ...

# %%
df.set_index('Country')
# Out:
#                      State  Yearcode_x                             Year  \
# Country
# India    Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# India    Jammu And Kashmir      2018.0  Calendar Year (Jan - Dec), 2018
# India    Jammu And Kashmir      2018.0                              NaN
# India    Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# India    Jammu And Kashmir      2018.0                              NaN
# India    Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# India    Jammu And Kashmir      2018.0                              NaN
# India    Jammu And Kashmir      2018.0                              NaN
# India    Jammu And Kashmir      2018.0  Calendar Year (Jan - Dec), 2018
# India    Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
#
#          Gender Residence type  Yearcode_y
# Country
# India    Female          Rural        2018
# India    Female          Total        2018
# ...

# %%
df.melt()
# Out:
#       variable  value
# 0      Country  India
# 1      Country  India
# 2      Country  India
# 3      Country  India
# 4      Country  India
# ..         ...    ...
# 65  Yearcode_y   2018
# 66  Yearcode_y   2018
# 67  Yearcode_y   2018
# 68  Yearcode_y   2018
# 69  Yearcode_y   2018
#
# [70 rows x 2 columns]

# %%
df.apply(lambda x: [1, 2], axis=1, result_type='expand')
# Out:
#    0  1
# 0  1  2
# 1  1  2
# 2  1  2
# 3  1  2
# 4  1  2
# 5  1  2
# 6  1  2
# 7  1  2
# 8  1  2
# 9  1  2

# %%
df.dropna(how='all')
# Out:
#   Country              State  Yearcode_x                             Year  \
# 0   India  Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# 1   India  Jammu And Kashmir      2018.0  Calendar Year (Jan - Dec), 2018
# 2   India  Jammu And Kashmir      2018.0                              NaN
# 3   India  Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# 4   India  Jammu And Kashmir      2018.0                              NaN
# 5   India  Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
# 6   India  Jammu And Kashmir      2018.0                              NaN
# 7   India  Jammu And Kashmir      2018.0                              NaN
# 8   India  Jammu And Kashmir      2018.0  Calendar Year (Jan - Dec), 2018
# 9   India  Jammu And Kashmir         NaN  Calendar Year (Jan - Dec), 2018
#
#    Gender Residence type  Yearcode_y
# 0  Female          Rural        2018
# 1  Female          Total        2018
# 2  Female          Urban        2018
# ...

# %%
df.fillna(0)
# Out:
#   Country              State  Yearcode_x                             Year  \
# 0   India  Jammu And Kashmir         0.0  Calendar Year (Jan - Dec), 2018
# 1   India  Jammu And Kashmir      2018.0  Calendar Year (Jan - Dec), 2018
# 2   India  Jammu And Kashmir      2018.0                                0
# 3   India  Jammu And Kashmir         0.0  Calendar Year (Jan - Dec), 2018
# 4   India  Jammu And Kashmir      2018.0                                0
# 5   India  Jammu And Kashmir         0.0  Calendar Year (Jan - Dec), 2018
# 6   India  Jammu And Kashmir      2018.0                                0
# 7   India  Jammu And Kashmir      2018.0                                0
# 8   India  Jammu And Kashmir      2018.0  Calendar Year (Jan - Dec), 2018
# 9   India  Jammu And Kashmir         0.0  Calendar Year (Jan - Dec), 2018
#
#    Gender Residence type  Yearcode_y
# 0  Female          Rural        2018
# 1  Female          Total        2018
# 2  Female          Urban        2018
# ...

# %%
df.groupby(['Residence type']).mean()
# Out:
#                 Yearcode_x  Yearcode_y
# Residence type
# Rural               2018.0      2018.0
# Total               2018.0      2018.0
# Urban               2018.0      2018.0

# %%
df.agg("mean", axis="columns")
# Out:
# C:\Users\Louis\AppData\Local\Temp\ipykernel_12800\1904844160.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.agg("mean", axis="columns")
# Series([], dtype: float64)
